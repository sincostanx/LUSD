# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import numpy as np
import pandas as pd
from metrics import *

# %%
score_summary = ScoreSummary("test_eval_result")
score_summary.add_results("ours")
score_summary.summarize()
# Out:
#    case  clip_t     l1  clip_i  clip_t_add  clip_t_change  l1_add  l1_change  \
# 0  ours   0.287  0.063     0.9       0.283           0.29   0.059      0.067
#
#    clip_i_add  clip_i_change  clip_auc    l1*  clip_i*  clip_auc_add  l1*_add  \
# 0       0.897          0.902     0.074  0.015    0.192         0.081    0.012
#
#    clip_i*_add  clip_auc_change  l1*_change  clip_i*_change
# 0        0.192            0.069       0.017           0.193

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
score_summary.plot_clip_r(ax=ax)
# Out:
# ours
